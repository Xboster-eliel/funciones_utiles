# %% [markdown]
# <a href="https://colab.research.google.com/github/Xboster-eliel/funciones_utiles/blob/main/Hoja_de_vida_streamlit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install -q streamlit

# %%
# %%writefile app_v1.py
# app_v1.py
# Ejecuta: streamlit run app_v1.py

# app_v1.py
# Ejecuta: streamlit run app_v1.py

import streamlit as st
from streamlit.components.v1 import html
from string import Template
from datetime import datetime

st.set_page_config(page_title="CV – Eliel Segura Perez", page_icon="📄", layout="wide")

# ---------------------------
# 1) DEFAULTS (evita KeyError)
# ---------------------------
DEFAULTS = {
    "name": "Eliel Segura Perez",
    "occupation": "Civil Engineer",
    "phone": "+57 318 542 7524",
    "email": "eliel.segura.4369@gmail.com",
    "addr_line1": "",
    "city": "Medellin, Colombia",
    "postal": "050042",
    "hello_title": "Data Analyst & Data Mining",
    "hello_text": "I am passionate about programming and continuous learning.",
    "quote_text": "Failure does not... no, it means nothing",
    "quote_author": "Antonio Gala.",
    "about_me": (
        "I am a civil engineer with a solid background in data analysis using Python "
        "for hydrological and hydraulic simulation, as well as their study. "
        "With complementary professional training in processes, methods, and construction project management, "
        "through the application of BIM methodologies. "
        "3D modeling assisted with the Revit tool (certified as a BIM modeler by Conconcreto), "
        "for the roles: architect, structural, MEP, and management (collisions, interferences, collaborations, etc.). "
        "Passionate about Hydrological and Hydraulic Simulation, process automation through Python, "
        "Creation of Geoportals, Computer Vision, Predictive Models, Machine Learning, Deep Learning, "
        "Big Data, Websites, and SQL Databases."
    ),
    "philosophy_intro": "If you can calculate it, you can program it.",
    "philosophy_body": (
        "I firmly believe that we can materialize our dreams and knowledge "
        "through effort, perseverance, and dedication. "
        "Through programming and continuous learning, I will help you make it a reality!"
    ),
    "traits": ["Pragmatic", "Honest", "Respectful", "Open-minded", "Self-taught", "Persistent", "Dedicated", "Persevering"],
    "interests_intro": "I am passionate about programming, LLM, AI, Machine Learning, and data science:",
    "interests": [
        "Computer Vision, Artificial Vision",
        "Classical Artificial Intelligence, Machine Learning",
        "Predictive Models (Regressive/Autoregressive)",
        "Web Development",
        "Big Data, Data Mining, Data Analysis",
        "Data Visualization and Databases/Storages",
        "Web Scraping",
        "GIS (Geographic Information System)"
    ],
    "facebook": "https://www.facebook.com/jlalovi",
    "twitter": "https://twitter.com/jlalovi",
    "linkedin": "https://www.linkedin.com/in/jlalovi/en",
    "year": str(datetime.now().year),
}

# ---------------------------
# 2) TUS DATOS (sobrescriben defaults)
# ---------------------------
DATA = {
    "hello_text": "I am passionate about programming and continuous learning.",
    "quote_text": "Failure does not... no, it means nothing",
    "quote_author": "Antonio Gala.",
    "about_me": (
        "I am a civil engineer with a solid background in data analysis using Python for hydrological and hydraulic simulation, as well as their study."
        "With complementary professional training in processes, methods, and construction project management, through the application of BIM methodologies."
        "3D modeling assisted with the Revit tool (certified as a BIM modeler by the company Conconcreto), for the roles: architect, structural, MEP, and management (collisions, interferences, collaborations, etc.)."
        "Passionate about Hydrological and Hydraulic Simulation, process automation through programming in Python,"
        "Creation of Geoportals, Computer Vision, Predictive Models, Machine Learning, Deep Learning, Big Data, Websites, and SQL Databases."
    ),
    "philosophy_intro": "If you can calculate it, you can program it.",
    "philosophy_body": (
        "I firmly believe that we can materialize our dreams and knowledge through effort, perseverance, and dedication."
        "Through programming and continuous learning, I will help you make it a reality!"
    ),
    "traits": ["Pragmatic", "Honest", "Respectful", "Open-minded", "Self-taught", "Persistent", "Dedicated", "Persevering"],
    "interests_intro": "I am passionate about programming, LLM, AI, Machine Learning, and data science:",
    "interests": [
        "Computer Vision, Artificial Vision",
        "Classical Artificial Intelligence, Machine Learning",
        "Predictive Models (Regressive/Autoregressive)",
        "Web Development",
        "Big Data, Data Mining, Data Analysis",
        "Data Visualization and Databases/Storages",
        "Web Scraping",
        "GIS (Geographic Information System)"
    ],
    "year": str(datetime.now().year),
}

# Añade nuevas secciones a DATA
DATA.update({
  "education": [
    {"degree": "M.Sc. Civil Engineering", "school": "Universidad X", "years": "2022–2024", "desc": "Énfasis en hidráulica."},
    {"degree": "B.Sc. Civil Engineering", "school": "Universidad Y", "years": "2016–2021", "desc": "Becario, promedio 4.5."},
  ],
  "skills": ["Python", "Pandas", "GIS", "SQL", "Streamlit"],
  "experience": [
    {"role":"Data Analyst", "company":"Empresa A", "years":"2023–Actual", "bullets":["ETL de datos","Dashboards en Streamlit"]},
    {"role":"Ingeniero Junior", "company":"Empresa B", "years":"2021–2023", "bullets":["Modelos HEC-HMS","QA/QC de datos"]},
  ],
  "projects": [
    {"name":"Geoportal Cuencas", "link":"https://ejemplo.com", "desc":"Mapa interactivo con capas WMS."},
  ],
  "awards": ["Beca Mérito 2020", "Top 10 Hackathon 2023"]
})

# Mezcla defaults + tus datos (tus claves mandan)  <<< MOVER ESTO ANTES de usar CTX
CTX = {**DEFAULTS, **DATA}

# ---------------------------
# 3) PRE-CÁLCULOS para Template
# ---------------------------
parts = CTX["name"].split()
first_name = parts[0]
last_name = " ".join(parts[1:]) if len(parts) > 1 else ""

traits_html = "\n".join(f"<li>{t}</li>" for t in CTX.get("traits", []))
interests_html = "\n".join(f"<li>{t}</li>" for t in CTX.get("interests", []))

# Nuevas secciones (se construyen DESPUÉS de definir CTX)
education_html = "\n".join(
  f"""
  <li>
    <h4>{e['degree']}</h4>
    <p><strong>{e['school']}</strong> — <em>{e['years']}</em></p>
    <p>{e.get('desc','')}</p>
  </li>
  """ for e in CTX.get("education", [])
)

skills_html = "\n".join(f"<li>{s}</li>" for s in CTX.get("skills", []))

experience_html = "\n".join(
  f"""
  <li>
    <h4>{x['role']} — <span class='purple'>{x['company']}</span> <em>({x['years']})</em></h4>
    <ul> {''.join(f'<li>{b}</li>' for b in x.get('bullets', []))} </ul>
  </li>
  """ for x in CTX.get("experience", [])
)

projects_html = "\n".join(
  f"<li><strong><a href='{p.get('link','#')}' target='_blank' rel='noopener'>{p['name']}</a></strong> — {p.get('desc','')}</li>"
  for p in CTX.get("projects", [])
)

awards_html = "\n".join(f"<li>{a}</li>" for a in CTX.get("awards", []))

# ---------------------------
# 4) HTML + CSS (Template)
# ---------------------------
HTML = Template(r"""
<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="utf-8" />
<meta name="viewport" content="width=device-width, initial-scale=1" />
<title>$name – CV</title>

<link href="https://fonts.googleapis.com/css2?family=Lato:ital,wght@0,300;0,400;1,300;1,400&display=swap" rel="stylesheet">
<link rel="stylesheet" href="https://weloveiconfonts.com/api/?family=entypo|fontawesome">
<link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.15.4/css/all.css"
      integrity="sha384-DyZ88mC6Up2uqS4h/KRgHuoeGwBcD4Ng9SiP4dIRy0EXTlnuz47vAwmeGwVChigm" crossorigin="anonymous"/>

<style>
[class*="entypo-"]:before { font-family: 'entypo', sans-serif; }
[class*="fontawesome-"]:before { font-family: 'FontAwesome', sans-serif; }
.clear { clear: both; }
.purple { color: #837c9a; }
.block { margin: 25px 30px; }
.block h1 { margin-left: -5px; font-weight: 200; }
.last.block { margin-bottom: 110px; }
.horizontal_list { margin: 0; padding: 0; list-style-type: none; }
.horizontal_list li { float: left; padding-left: 0; text-indent: 0; }
.horizontal_list li:before { content: none; }
.horizontal_line{ margin: 34px 0 0 30px; height: 26px; position: relative; }
.line_left, .line_right{ border-top: 1px solid #434247; width: 305px; margin-top: 13px; }
.line_left{ float: left; } .line_right { float: right; }
.left_circle, .central_circle, .right_circle { background: rgba(255,255,255,0.15); position: absolute; border-radius: 50px; }
.left_circle, .right_circle { width: 13px; height: 13px; top: 7px; }
.left_circle{ left: 314px; } .central_circle{ width: 26px; height: 26px; top: 0; left: 322px; }
.right_circle{ left: 343px; }
body { background: url(https://www.toptal.com/designers/subtlepatterns/patterns/dark_wall.png) repeat; margin: 0; }
h1,h2,h3,h4 { font-family: 'Lato', Helvetica, sans-serif; font-weight: 300; color: #48DA9B; }
h1 { font-size: 48px; margin: 20px 0; }
h2 { font-size: 28px; margin: 32px 0 24px; }
h3 { font-size: 24px; }
h4 { font-size: 18px; font-weight: 400; }
blockquote { font-style: italic; margin: 25px 0; padding-left: 20px; border-left: 2px solid #48DA9B; }
blockquote, p, a, li { font-family: 'Lato', Helvetica, sans-serif; font-weight: 300; font-size: 15px; color: #e4e3e8; }
a:focus { outline: none; }
ul { list-style: none; padding: 0; margin: 0; }
li { padding-left: 1em; text-indent: -.7em; }
li:before { content: "• "; color: #837c9a; font-size: 20px; padding-right: 8px; }
#main_container { width: 960px; margin: 0 auto; }
#header { height: 130px; border-bottom: 1px solid #403F44; }
.header_logotype_container { width: 260px; height: 130px; border-right: 1px solid #403F44; float: left; }
.header_menu_container { height: 130px; width: 699px; float: left; }
.header_menu_container a { font-family: 'Lato', Helvetica, sans-serif; }
#left_col { width: 260px; float: left; }
#content_container { width: 699px; border-left: 1px solid #403F44; float: left; }
#footer { width: 960px; height: 60px; border-top: 1px solid #403F44; display: inline-block; }
.logotype_name{ text-transform: uppercase; font-size: 32px; margin: 43px 0 0; }
.logotype_occupation{ text-transform: uppercase; margin-top: 5px; color: #5ce2af; font-size: 14px; letter-spacing: 2px; padding-left: 7px; }
.download_print_buttons { width: 260px; height: 45px; float: right; }
.download_print_buttons a { text-decoration: none; font-size: 12px; font-style: italic; line-height: 45px; padding: 16px 17px; background: #353638; display: inline-block; }
.download_print_buttons a:hover { background: #020609; }
.download_print_buttons .icon { color: #02070a; padding-right: 6px; font-style: normal; font-size: 18px; }
.download_print_buttons a:hover .icon { color: #e4e3e8; }
.header_menu { width: 699px; margin-top: 40px; margin-left: 5px; }
.header_menu a { text-decoration: none; padding: 0 20px; border-left: 1px solid #e4e3e8; font-size: 16px; font-weight: 400; }
.header_menu a.no_border { border-left: none; }
.header_menu a:hover { color: #837c9a; }
.profile_frame{ width: 230px; height: 260px; background: black; border: 1px solid #403F44; margin-top: 30px; }
.profile_picture{ width: 210px; height: 240px; margin:10px; background: url(//s3-us-west-2.amazonaws.com/s.cdpn.io/86033/profile/profile-512_3.jpg) 100% /210px no-repeat; }
.hello_content, .contact_details_content { margin-top: 25px; }
.hello_content{ width: 230px; }
.contact_details_content h2 + p.purple{ margin-top: 10px; }
.contact_details_content p{ margin: 0; }
.contact_details_content p.purple{ margin-top: 25px; }
.send_message_button, .special_button { margin-top: 25px; display: block; background: #48DA9B; width: 230px; height: 50px; position: relative; z-index: 1; }
.cut1:after { content: ""; position: absolute; bottom: -19px; left: -20px; width: 30px; height: 30px; z-index: 9; background: url(https://www.toptal.com/designers/subtlepatterns/patterns/dark_wall.png) repeat; transform: rotate(45deg); }
.cut2:before { content: ""; position: absolute; top: -19px; right: -20px; width: 30px; height: 30px; z-index: 9; background: url(https://www.toptal.com/designers/subtlepatterns/patterns/dark_wall.png) repeat; transform: rotate(45deg); }
.content { text-align: center; color: #04080b; width: 100%; height: 40px; position: absolute; z-index: 2; font: 18px 'Lato', Arial, sans-serif; margin: 0; padding: 16px 0 0; top: -4px; bottom: 10px; border-top: 1px solid #403F44; border-bottom: 1px solid #403F44; }
.send_message_button:hover, .special_button:hover { background: #29C782; }
.get_social_content { margin-top: 15px; }
.get_social_content h2{ margin-bottom: 8px; }
.social_icons { margin-left: -8px; }
.social_icons a { font-size: 35px; text-decoration: none; color: #000507; padding: 0 5px; }
.social_icons a span.invisible { display:none; }
.social_icons .facebook:hover{ background: #3b5998; color: #dfe3ee; border-top-right-radius: 50px; border-bottom-left-radius: 50px; }
.social_icons .twitter:hover{ background: #00B0ED; color: #fff; border-top-left-radius: 50px; border-bottom-right-radius: 50px; }
.social_icons .linkedin:hover{ background: #007bb6; color: #fff; border-top-right-radius: 50px; border-bottom-left-radius: 50px; }
.footer_name { font-style: italic; margin-top: 20px; }
.profile_quote { position: relative; }
.profile_quote p { font-size: 17px; width: 455px; }
.profile_quote .entypo-quote { color: #3d3a41; font-size: 80px; font-style: normal; position: absolute; top: -20px; right: 70px; cursor: default; }
.philosophy_content { margin-top: 20px; }
.philosophy_content p { margin: 0; width: 370px; float: left; }
.philosophy_content ul { float: left; padding-left: 40px; }
#btn-print, #btn-download { cursor: pointer; }

/* (Opcional) estilo tipo chip para skills */
#skills ul li { background:#353638; border:1px solid #403F44; border-radius:20px; padding:6px 12px; margin:4px 6px; }
</style>

</head>
<body>
  <div id="main_container">
    <!-- HEADER -->
    <div id="header">
      <div class="header_logotype_container">
        <h1 class="logotype_name">$first_name <span class="purple">$last_name</span></h1>
        <h2 class="logotype_occupation">$occupation</h2>
      </div>
      <div class="header_menu_container">
        <ul class="download_print_buttons horizontal_list">
          <li><a id="btn-download"><span class="icon entypo-download"></span>Download CV</a></li>
          <li><a id="btn-print"><span class="icon entypo-print"></span>Print CV</a></li>
        </ul>
        <div class="clear"></div>
        <ul class="header_menu horizontal_list">
          <li><a class="no_border purple" href="#profile">Profile</a></li>
          <li><a href="#education">Education</a></li>
          <li><a href="#skills">Skills</a></li>
          <li><a href="#experience">Work Experience</a></li>
          <li><a href="#projects">Featured Projects</a></li>
          <li><a href="#awards">Awards</a></li>
        </ul>
      </div>
    </div>

    <!-- LEFT COL -->
    <div id="left_col">
      <div class="profile_frame">
        <div class="profile_picture"></div>
      </div>
      <div class="hello_content">
        <h2>$hello_title</h2>
        <p>$hello_text</p>
      </div>
      <div class="contact_details_content">
        <h2>Contact details</h2>
        <p class="purple">Phone:</p>
        <p>$phone</p>
        <p class="purple">Email:</p>
        <p>$email</p>
        <p class="purple">Address:</p>
        <p>$addr_line1</p>
        <p>$city</p>
        <p>$postal</p>
      </div>
      <a href="mailto:$email" class="send_message_button">
        <span class="cut1"></span>
        <span class="cut2"></span>
        <span class="content">Send me a message <span class="fontawesome-double-angle-right"></span></span>
      </a>
      <div class="get_social_content">
        <h2>Get social</h2>
        <ul class="social_icons horizontal_list">
          <li><a class="facebook" href="$facebook" target="_blank" rel="noopener"><span class="entypo-facebook-circled"></span><span class="invisible">Facebook</span></a></li>
          <li><a class="twitter" href="$twitter" target="_blank" rel="noopener"><span class="entypo-twitter-circled"></span><span class="invisible">Twitter</span></a></li>
          <li><a class="linkedin" href="$linkedin" target="_blank" rel="noopener"><span class="entypo-linkedin-circled"></span><span class="invisible">LinkedIn</span></a></li>
        </ul>
      </div>
    </div>

    <!-- PROFILE CONTENT -->
    <div id="content_container">
      <div class="block" id="profile">
        <h1>Profile</h1>
        <blockquote class="profile_quote">
          <p>"$quote_text"</p>
          <p>$quote_author</p>
          <span class="entypo-quote"></span>
        </blockquote>
      </div>
      <div class="block">
        <h2>A few words about me</h2>
        <p>$about_me</p>
      </div>

      <div class="horizontal_line">
        <div class="line_left"></div>
        <div class="left_circle"></div>
        <div class="central_circle"></div>
        <div class="right_circle"></div>
        <div class="line_right"></div>
      </div>

      <div class="block">
        <h2>Philosophy</h2>
        <p>$philosophy_intro</p>
        <div class="philosophy_content">
          <p>$philosophy_body</p>
          <ul>
            $traits
          </ul>
          <div class="clear"></div>
        </div>
      </div>

      <div class="horizontal_line">
        <div class="line_left"></div>
        <div class="left_circle"></div>
        <div class="central_circle"></div>
        <div class="right_circle"></div>
        <div class="line_right"></div>
      </div>

      <div class="last block">
        <h2>Interests & Hobbies</h2>
        <p>$interests_intro</p>
        <ul>
          $interests
        </ul>
      </div>
    </div>

    <!-- SECCIONES NUEVAS -->
    <div class="horizontal_line">
      <div class="line_left"></div><div class="left_circle"></div>
      <div class="central_circle"></div><div class="right_circle"></div>
      <div class="line_right"></div>
    </div>
    <div class="block" id="education">
      <h2>Education</h2>
      <ul>$education</ul>
    </div>

    <div class="horizontal_line">
      <div class="line_left"></div><div class="left_circle"></div>
      <div class="central_circle"></div><div class="right_circle"></div>
      <div class="line_right"></div>
    </div>
    <div class="block" id="skills">
      <h2>Skills</h2>
      <ul class="horizontal_list">$skills</ul>
      <div class="clear"></div>
    </div>

    <div class="horizontal_line">
      <div class="line_left"></div><div class="left_circle"></div>
      <div class="central_circle"></div><div class="right_circle"></div>
      <div class="line_right"></div>
    </div>
    <div class="block" id="experience">
      <h2>Work Experience</h2>
      <ul>$experience</ul>
    </div>

    <div class="horizontal_line">
      <div class="line_left"></div><div class="left_circle"></div>
      <div class="central_circle"></div><div class="right_circle"></div>
      <div class="line_right"></div>
    </div>
    <div class="block" id="projects">
      <h2>Featured Projects</h2>
      <ul>$projects</ul>
    </div>

    <div class="horizontal_line">
      <div class="line_left"></div><div class="left_circle"></div>
      <div class="central_circle"></div><div class="right_circle"></div>
      <div class="line_right"></div>
    </div>
    <div class="block" id="awards">
      <h2>Awards</h2>
      <ul>$awards</ul>
    </div>

    <div class="clear"></div>

    <div id="footer">
      <p class="footer_name">$name CV $year</p>
    </div>
  </div>

<script>
document.getElementById('btn-download').addEventListener('click', function(e){
  e.preventDefault();
  const blob = new Blob([document.documentElement.outerHTML], {type: 'text/html'});
  const a = document.createElement('a');
  a.href = URL.createObjectURL(blob);
  a.download = 'cv.html';
  document.body.appendChild(a);
  a.click();
  URL.revokeObjectURL(a.href);
  a.remove();
});
document.getElementById('btn-print').addEventListener('click', function(e){
  e.preventDefault();
  window.print();
});
</script>

</body>
</html>
""")

# ---------------------------
# 5) Relleno del template (seguro)
# ---------------------------
ctx_full = {
  **CTX,
  "first_name": first_name,
  "last_name": last_name,
  "traits": traits_html,
  "interests": interests_html,
  "education": education_html,
  "skills": skills_html,
  "experience": experience_html,
  "projects": projects_html,
  "awards": awards_html,
}

html_filled = HTML.safe_substitute(ctx_full)

# ---------------------------
# 6) UI Streamlit
# ---------------------------
st.download_button(
    "⬇️ Descargar HTML",
    data=html_filled.encode("utf-8"),
    file_name="cv.html",
    mime="text/html",
)

html(html_filled, height=1950, scrolling=True)
# Out:
# Overwriting app_v1.py

# %%
get_ipython().system('streamlit run app_v1.py')
# Out:
# ^C
